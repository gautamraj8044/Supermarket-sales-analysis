# %%
import pandas as pd
data = pd.read_csv("sales.csv")
data.head()

# %%
data['Invoice ID']

# %%
data['Category'].unique()

# %%
data.info

# %%
data.shape
# Out:
# (1000, 13)

# %%
data.iloc[4]
# Out:
# Invoice ID    197763430
# Date          2/18/2018
# Time              15:31
# Gender           Female
# Location      Park lane
# City             Dallas
# Member               No
# Category          Books
# Price                82
# Quantity              5
# Total               410
# Payment            Cash
# Rating                4
# Name: 4, dtype: object

# %%
data.head(1)
# Out:
#    Invoice ID       Date   Time Gender    Location     City Member   Category  \
# 0   460489604  1/25/2018  16:46   Male  Brookfield  NewYork    Yes  Groceries
#
#    Price  Quantity  Total Payment  Rating
# 0     30         1     30    Cash       2

# %%
data[data['Gender'] == "Male"]
# Out:
#      Invoice ID       Date   Time Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46   Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33   Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55   Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21   Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24   Male    Park lane   Dallas     No
# ..          ...        ...    ...    ...          ...      ...    ...
# 992   927909627   3/2/2018  13:35   Male   Brookfield  NewYork     No
# 994   446582560  1/31/2018  19:00   Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19   Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17   Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44   Male   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data[data['Gender'] =='Female'].head()
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 3    Sporting     89         4    356    Gpay       1
# 4       Books     82         5    410    Cash       4
# 9       Books     80         2    160    Cash       4
# 10  Furniture     35         4    140    Gpay       4

# %%
data[data['Total'] > 100]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
data['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
data[data['Payment'] == 'Cash']
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7     188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 990   752407865  1/15/2018  10:01    Male  Water tower  Chicago    Yes
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data.query('City == "NewYork"')
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 5     263634050   3/9/2018  17:55    Male  Brookfield  NewYork    Yes
# 10    388412668  2/26/2018  11:32  Female  Brookfield  NewYork     No
# 14    547572603  3/21/2018  13:23  Female  Brookfield  NewYork     No
# 15    355981315  2/15/2018  15:47  Female  Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...         ...      ...    ...
# 991   699906043  2/15/2018  12:58    Male  Brookfield  NewYork    Yes
# 992   927909627   3/2/2018  13:35    Male  Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female  Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male  Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female  Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
data.query('100<Total>200')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 8     325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 987   245049016  1/20/2018  10:03  Female    Park lane   Dallas     No
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 3     Sporting     89         4    356    Gpay       1
# ...

# %%
data.query('50<Price<90')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 987   245049016  1/20/2018  10:03  Female    Park lane   Dallas     No
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 992   927909627   3/2/2018  13:35    Male   Brookfield  NewYork     No
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 2     Clothing     57         2    114    Cash       5
# ...

# %%
data.query('Payment =="Cash" & City == "NewYork" & Total < 50')
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 81    336967276  1/19/2018  17:54    Male  Brookfield  NewYork     No
# 95    842361554  1/14/2018  16:17    Male  Brookfield  NewYork    Yes
# 159   582323814  1/13/2018  20:06    Male  Brookfield  NewYork    Yes
# 238   565456402  1/23/2018  14:51  Female  Brookfield  NewYork     No
# 257   874941247   3/1/2018  11:24  Female  Brookfield  NewYork     No
# 301   479562097  2/16/2018  14:03  Female  Brookfield  NewYork     No
# 382   376812677  1/10/2018  18:04  Female  Brookfield  NewYork     No
# 401   196926207   3/3/2018  13:08  Female  Brookfield  NewYork    Yes
# 499   253349866  2/16/2018  19:06    Male  Brookfield  NewYork    Yes
# 506   187709802  1/24/2018  10:43    Male  Brookfield  NewYork    Yes
# 514   148516620   2/8/2018  12:29  Female  Brookfield  NewYork     No
# ...

# %%
data.sum()
# Out:
# Invoice ID                                         494493053341
# Date          1/25/20183/19/20182/25/20181/22/20182/18/20183...
# Time          16:4616:4813:3313:3815:3117:5513:2113:2415:331...
# Gender        MaleFemaleMaleFemaleFemaleMaleMaleMaleMaleFema...
# Location      BrookfieldWater towerWater towerPark lanePark ...
# City          NewYorkChicagoChicagoDallasDallasNewYorkChicag...
# Member        YesYesNoYesNoYesNoNoYesNoNoNoNoYesNoYesYesYesY...
# Category      GroceriesFashionClothingSportingBooksClothingC...
# Price                                                     51112
# Quantity                                                   4059
# Total                                                    207788
# Payment       CashCardCashGpayCashGpayCashCashCardCashGpayCa...
# Rating                                                     2972
# dtype: object

# %%
data['Total'].sum()
# Out:
# 207788

# %%
data['Quantity'].max()
# Out:
# 7

# %%
data.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
data.min()
# Out:
# Invoice ID        661405
# Date            1/1/2018
# Time               10:00
# Gender            Female
# Location      Brookfield
# City             Chicago
# Member                No
# Category           Books
# Price                  1
# Quantity               1
# Total                  1
# Payment             Card
# Rating                 1
# dtype: object

# %%
data['Price'].min()
# Out:
# 1

# %%
data.max()['Total']
# Out:
# 693

# %%
data["Total"].max()
# Out:
# 693

# %%
data[data['Total'] == data['Total'].min()]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
# data.mean()

# %%
data['Total'].mean()
# Out:
# 207.788

# %%
data.groupby('Payment').sum()
# Out:
#            Invoice ID                                               Date  \
# Payment
# Card     158673374503  3/19/20181/18/20183/15/20182/15/20182/24/20182...
# Cash     162478763694  1/25/20182/25/20182/18/20183/4/20183/8/20182/2...
# Gpay     173340915144  1/22/20183/9/20182/26/20181/18/20183/21/20182/...
#
#                                                       Time  \
# Payment
# Card     16:4815:3312:1215:4719:3113:0011:5715:0912:041...
# Cash     16:4613:3315:3113:2113:2416:0511:1218:1812:501...
# Gpay     13:3817:5511:3215:2013:2315:5910:5816:0810:111...
#
#                                                     Gender  \
# Payment
# Card     FemaleMaleMaleFemaleFemaleMaleMaleFemaleFemale...
# Cash     MaleMaleFemaleMaleMaleFemaleMaleMaleMaleFemale...
# Gpay     FemaleMaleFemaleFemaleFemaleFemaleFemaleFemale...
#
#                                                   Location  \
# Payment
# Card     Water towerPark lanePark laneBrookfieldBrookfi...
# ...

# %%
data.groupby("City").max()
# Out:
#          Invoice ID      Date   Time Gender     Location Member  Category  \
# City
# Chicago   994218721  3/9/2018  20:55   Male  Water tower    Yes  Sporting
# Dallas    999023942  3/9/2018  20:59   Male    Park lane    Yes  Sporting
# NewYork   999665753  3/9/2018  20:59   Male   Brookfield    Yes  Sporting
#
#          Price  Quantity  Total Payment  Rating
# City
# Chicago     99         7    693    Gpay       5
# Dallas     100         7    693    Gpay       5
# NewYork    100         7    686    Gpay       5

# %%
# data.get_group('Location')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11928\2651825083.py in ?()
# ----> 1 data.get_group('Location')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
df6= data.groupby(['Location', 'Payment'])

# %%
df6.first()
# Out:
#                      Invoice ID       Date   Time  Gender     City Member  \
# Location    Payment
# Brookfield  Card      355981315  2/15/2018  15:47  Female  NewYork    Yes
#             Cash      460489604  1/25/2018  16:46    Male  NewYork    Yes
#             Gpay      263634050   3/9/2018  17:55    Male  NewYork    Yes
# Park lane   Card      325637547  1/18/2018  15:33    Male   Dallas    Yes
#             Cash      197763430  2/18/2018  15:31  Female   Dallas     No
#             Gpay      487313402  1/22/2018  13:38  Female   Dallas    Yes
# Water tower Card      471006167  3/19/2018  16:48  Female  Chicago    Yes
#             Cash      411909258  2/25/2018  13:33    Male  Chicago     No
#             Gpay      942406749  1/18/2018  15:20  Female  Chicago    Yes
#
#                       Category  Price  Quantity  Total  Rating
# Location    Payment
# Brookfield  Card      Clothing     78         5    390       5
# ...

# %%
df6= data.groupby(['Location', 'Payment'])['Total'].sum()
df6
# Out:
# Location     Payment
# Brookfield   Card       23200
#              Cash       24138
#              Gpay       24803
# Park lane    Card       22851
#              Cash       22341
#              Gpay       25240
# Water tower  Card       18213
#              Cash       26164
#              Gpay       20838
# Name: Total, dtype: int64

# %%
df6 = data.groupby(['Location', 'Payment'],as_index=False)['Total'].sum()

# %%
df6
# Out:
#       Location Payment  Total
# 0   Brookfield    Card  23200
# 1   Brookfield    Cash  24138
# 2   Brookfield    Gpay  24803
# 3    Park lane    Card  22851
# 4    Park lane    Cash  22341
# 5    Park lane    Gpay  25240
# 6  Water tower    Card  18213
# 7  Water tower    Cash  26164
# 8  Water tower    Gpay  20838

# %%
data.head(1)
# Out:
#    Invoice ID       Date   Time Gender    Location     City Member   Category  \
# 0   460489604  1/25/2018  16:46   Male  Brookfield  NewYork    Yes  Groceries
#
#    Price  Quantity  Total Payment  Rating
# 0     30         1     30    Cash       2

# %%
data.groupby(['Location'])['Total'].sum()
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
location_list = data.groupby(['Location'])

# %%
# ls = [x for x,y in location_list]
# ls

# %%
location_list = data['Location'].unique()

# %%
location_list
# Out:
# array(['Brookfield', 'Water tower', 'Park lane'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location_list,data.groupby(['Location'])['Total'].sum())
plt.show()

# %%
location_list
# Out:
# array(['Brookfield', 'Water tower', 'Park lane'], dtype=object)

# %%
# ls = [x for x,y in location_list]
# type(ls)

# %%
# ls1= [x for x in location_list]

# %%
# ls1

# %%
plt.pie(data.groupby(['Location']).sum()["Total"],labels = location_list)
plt.show()

# %%
data.groupby('Location').count()
# Out:
#              Invoice ID  Date  Time  Gender  City  Member  Category  Price  \
# Location
# Brookfield          340   340   340     340   340     340       340    340
# Park lane           332   332   332     332   332     332       332    332
# Water tower         328   328   328     328   328     328       328    328
#
#              Quantity  Total  Payment  Rating
# Location
# Brookfield        340    340      340     340
# Park lane         332    332      332     332
# Water tower       328    328      328     328

# %%
data.groupby(['Location',"Gender"]).count()
# Out:
#                     Invoice ID  Date  Time  City  Member  Category  Price  \
# Location    Gender
# Brookfield  Female         179   179   179   179     179       179    179
#             Male           161   161   161   161     161       161    161
# Park lane   Female         179   179   179   179     179       179    179
#             Male           153   153   153   153     153       153    153
# Water tower Female         143   143   143   143     143       143    143
#             Male           185   185   185   185     185       185    185
#
#                     Quantity  Total  Payment  Rating
# Location    Gender
# Brookfield  Female       179    179      179     179
#             Male         161    161      161     161
# Park lane   Female       179    179      179     179
#             Male         153    153      153     153
# Water tower Female       143    143      143     143
#             Male         185    185      185     185

# %%
s = data.groupby(['Location',"Gender"]).count()['Invoice ID']

# %%
s
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
s.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Location,Gender'>

# %%
s1=s.unstack(level=0)
s1.T
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
s1.T.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Location'>

# %%
data.head(3)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# 2   Clothing     57         2    114    Cash       5

# %%
df1 = data.groupby(['Location','Member']).count()['Invoice ID']

# %%
df1
# Out:
# Location     Member
# Brookfield   No        173
#              Yes       167
# Park lane    No        167
#              Yes       165
# Water tower  No        159
#              Yes       169
# Name: Invoice ID, dtype: int64

# %%
df1.unstack(level=0).T.plot(kind = 'bar')
plt.show()

# %%
data.groupby(['Location']).mean()['Rating']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
data.groupby(['Location']).mean()['Rating'].plot(kind = 'bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
data.head(2)

# %%
data.groupby(['City', 'Gender']).count()['Invoice ID']

# %%
 data.groupby(['City', 'Gender']).count()['Invoice ID'].T.unstack(level=0).plot(kind = 'bar')

# %%
data.head(1)

# %%
data.groupby('Gender')['Total'].sum().plot(kind = 'bar')

# %%
data.head(1)

# %%
data.groupby(['Category', 'Gender']).sum()['Quantity'].unstack(level=0).T.diff().hist()

# %%
data.head(2)

# %%
pd.to_datetime(data['Date']).dt.day

# %%
data['Day'] = pd.to_datetime(data['Date']).dt.day

# %%
data

# %%
data.groupby('Day').sum()['Total'].plot()
